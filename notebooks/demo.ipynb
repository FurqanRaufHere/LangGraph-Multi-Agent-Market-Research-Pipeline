# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.graph import run
print("Demo notebook ready.")
# Out:
# Demo notebook ready.

# %%
result_happy = run("market size of textile industry in Pakistan 2025")
print(result_happy["outputs"])
print("Violations:", result_happy["violations"])
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ...

# %%
from src.agents import WriterAgent

def broken_writer_run(self, state):
    state["failure_count"] += 1
    state["violations"].append("forced_writer_failure")
    return state

WriterAgent.run = broken_writer_run

result_fail = run("AI adoption in Pakistan healthcare")
print(result_fail["outputs"])
print("Violations:", result_fail["violations"])
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Request error for https://www.researchgate.net/publication/373950823_Artificial_Intelligence_and_the_Future_of_Healthcare_in_Pakistan_Opportunities_and_Challenges: 403 Client Error: Forbidden for url: https://www.researchgate.net/publication/373950823_Artificial_Intelligence_and_the_Future_of_Healthcare_in_Pakistan_Opportunities_and_Challenges
# ...
